# %% [markdown]
# # Retrieve Data
# Data is retrived from [Global Database of Events, Language and Tone (GDELT)](https://www.gdeltproject.org), the data is taken and filtered specifically for the Indonesia collected from **January 2018 - October 2018**.
#
# Firstly, we loop to download the GDELT data, extract the files, read source country data as the filter; the source country data will give us the source country of every website domain; the last, read and put it into the database. The Geojson data will give us the lattitude and longtidue of every country.
#
# The GDELT data contains two types of tables `Events Database` and `Global Knowledge Graph (GKG)`
#
# Below an example script to download GDELT data with country code `ID`. Then from CSV can be moved to MySQL database

# %%
# create folders
import os

def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)
        

createFolder('./rawdata/events/result')
createFolder('./rawdata/gkg/result')

# %% [markdown]
# ## Getting `Events` data from GDELT

# %%
import requests
import lxml.html as lh

gdelt_base_url = 'http://data.gdeltproject.org/events/'

# get the list of all the links on the gdelt file page
page = requests.get(gdelt_base_url+'index.html')
doc = lh.fromstring(page.content)
link_list = doc.xpath("//*/ul/li/a/@href")

# separate out those links that begin with four digits
file_list = [x for x in link_list if str.isdigit(x[0:4])]
# file_list = file_list[85:]
# print(file_list)

infilecounter = 0
outfilecounter = 0

import os.path
import urllib.request
import zipfile
import glob
import operator
import pandas as pd

local_path = 'rawdata/events/'
fips_country_code = 'ID'

# %%
# set the month of the data collection
filemonth = ['201801', '201802', '201803', '201804', '201805', '201806', '201807', '201808', '201809', '201810']

## show the list of the months

#for compressed_file in file_list[infilecounter:]:
#    if any(c in compressed_file for c in filemonth):
#        print(compressed_file)

# %%
for compressed_file in file_list[infilecounter:]:
    if not any(c in compressed_file for c in filemonth):
        continue
        
    print(infilecounter, ' - ', compressed_file)

    # if we dont have the compressed file stored locally, go get it. Keep trying if necessary.
    while not os.path.isfile(local_path + compressed_file):
        print('downloading, ')
#         urllib.request.urlretrieve(url=gdelt_base_url + compressed_file,
#         filename=local_path + compressed_file)
        
        resp = requests.get(url=gdelt_base_url + compressed_file)

        # assuming the subdirectory tempdata has been created:
        zfile = open(local_path + compressed_file, 'wb')
        zfile.write(resp.content)
        zfile.close()

    # extract the contents of the compressed file to a temporary directory
    print('extracting,'),
    z = zipfile.ZipFile(file=local_path + compressed_file, mode='r')
    z.extractall(path=local_path + 'tmp/')

    # parse each of the csv files in the working directory,
    print('parsing,'),

    for infile_name in glob.glob(local_path + 'tmp/*'):
        outfile_name = local_path + 'result/' + fips_country_code + '%04i.tsv' % outfilecounter
        # open the infile and outfile
                
        with open(infile_name, mode='r', encoding="utf8") as infile, open(outfile_name, mode='w', encoding="utf8") as outfile:
            for line in infile:
                # extract lines with our interest country code
                if fips_country_code in operator.itemgetter(51, 37, 44)(line.split('\t')):
                    outfile.write(line)
            outfilecounter += 1

        # delete the temporary file
        os.remove(infile_name)
    infilecounter += 1
    print('done')
# Out:
# 0  -  20181031.export.CSV.zip
# extracting,
# parsing,
# done
# 1  -  20181030.export.CSV.zip
# extracting,
# parsing,
# done
# 2  -  20181029.export.CSV.zip
# extracting,
# parsing,
# done
# 3  -  20181028.export.CSV.zip
# extracting,
# parsing,
# done
# 4  -  20181027.export.CSV.zip
# extracting,
# parsing,
# done
# 5  -  20181026.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 6  -  20181025.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 7  -  20181024.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 8  -  20181023.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 9  -  20181022.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 10  -  20181021.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 11  -  20181020.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 12  -  20181019.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 13  -  20181018.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 14  -  20181017.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 15  -  20181016.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 16  -  20181015.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 17  -  20181014.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 18  -  20181013.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 19  -  20181012.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 20  -  20181011.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 21  -  20181010.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 22  -  20181009.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 23  -  20181008.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 24  -  20181007.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 25  -  20181006.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 26  -  20181005.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 27  -  20181004.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 28  -  20181003.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 29  -  20181002.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 30  -  20181001.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 31  -  20180930.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 32  -  20180929.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 33  -  20180928.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 34  -  20180927.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 35  -  20180926.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 36  -  20180925.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 37  -  20180924.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 38  -  20180923.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 39  -  20180922.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 40  -  20180921.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 41  -  20180920.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 42  -  20180919.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 43  -  20180918.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 44  -  20180917.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 45  -  20180916.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 46  -  20180915.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 47  -  20180914.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 48  -  20180913.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 49  -  20180912.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 50  -  20180911.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 51  -  20180910.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 52  -  20180909.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 53  -  20180908.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 54  -  20180907.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 55  -  20180906.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 56  -  20180905.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 57  -  20180904.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 58  -  20180903.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 59  -  20180902.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 60  -  20180901.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 61  -  20180831.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 62  -  20180830.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 63  -  20180829.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 64  -  20180828.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 65  -  20180827.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 66  -  20180826.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 67  -  20180825.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 68  -  20180824.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 69  -  20180823.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 70  -  20180822.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 71  -  20180821.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 72  -  20180820.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 73  -  20180819.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 74  -  20180818.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 75  -  20180817.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 76  -  20180816.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 77  -  20180815.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 78  -  20180814.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 79  -  20180813.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 80  -  20180812.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 81  -  20180811.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 82  -  20180810.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 83  -  20180809.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 84  -  20180808.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 85  -  20180807.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 86  -  20180806.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 87  -  20180805.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 88  -  20180804.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 89  -  20180803.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 90  -  20180802.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 91  -  20180801.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 92  -  20180731.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 93  -  20180730.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 94  -  20180729.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 95  -  20180728.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 96  -  20180727.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 97  -  20180726.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 98  -  20180725.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 99  -  20180724.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 100  -  20180723.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 101  -  20180722.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 102  -  20180721.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 103  -  20180720.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 104  -  20180719.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 105  -  20180718.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 106  -  20180717.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 107  -  20180716.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 108  -  20180715.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 109  -  20180714.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 110  -  20180713.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 111  -  20180712.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 112  -  20180711.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 113  -  20180710.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 114  -  20180709.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 115  -  20180708.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 116  -  20180707.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 117  -  20180706.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 118  -  20180705.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 119  -  20180704.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 120  -  20180703.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 121  -  20180702.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 122  -  20180701.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 123  -  20180630.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 124  -  20180629.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 125  -  20180628.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 126  -  20180627.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 127  -  20180626.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 128  -  20180625.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 129  -  20180624.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 130  -  20180623.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 131  -  20180622.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 132  -  20180621.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 133  -  20180620.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 134  -  20180619.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 135  -  20180618.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 136  -  20180617.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 137  -  20180616.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 138  -  20180615.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 139  -  20180614.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 140  -  20180613.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 141  -  20180612.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 142  -  20180611.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 143  -  20180610.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 144  -  20180609.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 145  -  20180608.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 146  -  20180607.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 147  -  20180606.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 148  -  20180605.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 149  -  20180604.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 150  -  20180603.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 151  -  20180602.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 152  -  20180601.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 153  -  20180531.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 154  -  20180530.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 155  -  20180529.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 156  -  20180528.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 157  -  20180527.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 158  -  20180526.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 159  -  20180525.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 160  -  20180524.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 161  -  20180523.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 162  -  20180522.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 163  -  20180521.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 164  -  20180520.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 165  -  20180519.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 166  -  20180518.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 167  -  20180517.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 168  -  20180516.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 169  -  20180515.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 170  -  20180514.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 171  -  20180513.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 172  -  20180512.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 173  -  20180511.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 174  -  20180510.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 175  -  20180509.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 176  -  20180508.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 177  -  20180507.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 178  -  20180506.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 179  -  20180505.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 180  -  20180504.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 181  -  20180503.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 182  -  20180502.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 183  -  20180501.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 184  -  20180430.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 185  -  20180429.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 186  -  20180428.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 187  -  20180427.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 188  -  20180426.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 189  -  20180425.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 190  -  20180424.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 191  -  20180423.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 192  -  20180422.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 193  -  20180421.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 194  -  20180420.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 195  -  20180419.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 196  -  20180418.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 197  -  20180417.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 198  -  20180416.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 199  -  20180415.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 200  -  20180414.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 201  -  20180413.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 202  -  20180412.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 203  -  20180411.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 204  -  20180410.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 205  -  20180409.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 206  -  20180408.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 207  -  20180407.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 208  -  20180406.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 209  -  20180405.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 210  -  20180404.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 211  -  20180403.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 212  -  20180402.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 213  -  20180401.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 214  -  20180331.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 215  -  20180330.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 216  -  20180329.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 217  -  20180328.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 218  -  20180327.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 219  -  20180326.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 220  -  20180325.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 221  -  20180324.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 222  -  20180323.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 223  -  20180322.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 224  -  20180321.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 225  -  20180320.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 226  -  20180319.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 227  -  20180318.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 228  -  20180317.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 229  -  20180316.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 230  -  20180315.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 231  -  20180314.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 232  -  20180313.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 233  -  20180312.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 234  -  20180311.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 235  -  20180310.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 236  -  20180309.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 237  -  20180308.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 238  -  20180307.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 239  -  20180306.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 240  -  20180305.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 241  -  20180304.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 242  -  20180303.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 243  -  20180302.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 244  -  20180301.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 245  -  20180228.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 246  -  20180227.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 247  -  20180226.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 248  -  20180225.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 249  -  20180224.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 250  -  20180223.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 251  -  20180222.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 252  -  20180221.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 253  -  20180220.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 254  -  20180219.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 255  -  20180218.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 256  -  20180217.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 257  -  20180216.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 258  -  20180215.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 259  -  20180214.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 260  -  20180213.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 261  -  20180212.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 262  -  20180211.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 263  -  20180210.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 264  -  20180209.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 265  -  20180208.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 266  -  20180207.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 267  -  20180206.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 268  -  20180205.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 269  -  20180204.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 270  -  20180203.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 271  -  20180202.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 272  -  20180201.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 273  -  20180131.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 274  -  20180130.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 275  -  20180129.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 276  -  20180128.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 277  -  20180127.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 278  -  20180126.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 279  -  20180125.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 280  -  20180124.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 281  -  20180123.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 282  -  20180122.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 283  -  20180121.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 284  -  20180120.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 285  -  20180119.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 286  -  20180118.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 287  -  20180117.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 288  -  20180116.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 289  -  20180115.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 290  -  20180114.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 291  -  20180113.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 292  -  20180112.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 293  -  20180111.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 294  -  20180110.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 295  -  20180109.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 296  -  20180108.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 297  -  20180107.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 298  -  20180106.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 299  -  20180105.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 300  -  20180104.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 301  -  20180103.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 302  -  20180102.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done
# 303  -  20180101.export.CSV.zip
# downloading,
# extracting,
# parsing,
# done

# %% [markdown]
# ### Import data into SQL Database
# Import all data `Events` into **gdelt_id_data** database in the `gdelt_events` table

# %%
import pymysql
import pandas as pd
from sqlalchemy import create_engine

host = 'localhost'
port = '3306'
username = 'root'
password = ''
database = 'gdelt_id_data'

# Create Connection to database
engine = create_engine('mysql+pymysql://'+username+':'+password+'@'+host+':'+port+'/'+database)
#engine = create_engine('mysql+pymysql://root: @localhost:3306/gdelt_id_data')
    
# Note: We use pymysql instead of sqlalchemy because sqlalchemy
# somehow don't allow the text query. Strange bug.

'''
conn = pymysql.connect(
    host=host,
    port=int(port),
    user=username,
    passwd=password,
    db=database,
    charset='utf8mb4')
'''


def run(sql):
    df = pd.read_sql_query(sql, engine)
    return df

# %%
from os import listdir
from os.path import isfile, join

folder_id = './rawdata/events/result/'
files = [f for f in listdir(folder_id) if isfile(join(folder_id, f)) if not f.startswith('.')]
print(files)
# Out:
# ['ID0000.tsv', 'ID0001.tsv', 'ID0002.tsv', 'ID0003.tsv', 'ID0004.tsv', 'ID0005.tsv', 'ID0006.tsv', 'ID0007.tsv', 'ID0008.tsv', 'ID0009.tsv', 'ID0010.tsv', 'ID0011.tsv', 'ID0012.tsv', 'ID0013.tsv', 'ID0014.tsv', 'ID0015.tsv', 'ID0016.tsv', 'ID0017.tsv', 'ID0018.tsv', 'ID0019.tsv', 'ID0020.tsv', 'ID0021.tsv', 'ID0022.tsv', 'ID0023.tsv', 'ID0024.tsv', 'ID0025.tsv', 'ID0026.tsv', 'ID0027.tsv', 'ID0028.tsv', 'ID0029.tsv', 'ID0030.tsv', 'ID0031.tsv', 'ID0032.tsv', 'ID0033.tsv', 'ID0034.tsv', 'ID0035.tsv', 'ID0036.tsv', 'ID0037.tsv', 'ID0038.tsv', 'ID0039.tsv', 'ID0040.tsv', 'ID0041.tsv', 'ID0042.tsv', 'ID0043.tsv', 'ID0044.tsv', 'ID0045.tsv', 'ID0046.tsv', 'ID0047.tsv', 'ID0048.tsv', 'ID0049.tsv', 'ID0050.tsv', 'ID0051.tsv', 'ID0052.tsv', 'ID0053.tsv', 'ID0054.tsv', 'ID0055.tsv', 'ID0056.tsv', 'ID0057.tsv', 'ID0058.tsv', 'ID0059.tsv', 'ID0060.tsv', 'ID0061.tsv', 'ID0062.tsv', 'ID0063.tsv', 'ID0064.tsv', 'ID0065.tsv', 'ID0066.tsv', 'ID0067.tsv', 'ID0068.tsv', 'ID0069.tsv', 'ID0070.tsv', 'ID0071.tsv', 'ID0072.tsv', 'ID0073.tsv', 'ID0074.tsv', 'ID0075.tsv', 'ID0076.tsv', 'ID0077.tsv', 'ID0078.tsv', 'ID0079.tsv', 'ID0080.tsv', 'ID0081.tsv', 'ID0082.tsv', 'ID0083.tsv', 'ID0084.tsv', 'ID0085.tsv', 'ID0086.tsv', 'ID0087.tsv', 'ID0088.tsv', 'ID0089.tsv', 'ID0090.tsv', 'ID0091.tsv', 'ID0092.tsv', 'ID0093.tsv', 'ID0094.tsv', 'ID0095.tsv', 'ID0096.tsv', 'ID0097.tsv', 'ID0098.tsv', 'ID0099.tsv', 'ID0100.tsv', 'ID0101.tsv', 'ID0102.tsv', 'ID0103.tsv', 'ID0104.tsv', 'ID0105.tsv', 'ID0106.tsv', 'ID0107.tsv', 'ID0108.tsv', 'ID0109.tsv', 'ID0110.tsv', 'ID0111.tsv', 'ID0112.tsv', 'ID0113.tsv', 'ID0114.tsv', 'ID0115.tsv', 'ID0116.tsv', 'ID0117.tsv', 'ID0118.tsv', 'ID0119.tsv', 'ID0120.tsv', 'ID0121.tsv', 'ID0122.tsv', 'ID0123.tsv', 'ID0124.tsv', 'ID0125.tsv', 'ID0126.tsv', 'ID0127.tsv', 'ID0128.tsv', 'ID0129.tsv', 'ID0130.tsv', 'ID0131.tsv', 'ID0132.tsv', 'ID0133.tsv', 'ID0134.tsv', 'ID0135.tsv', 'ID0136.tsv', 'ID0137.tsv', 'ID0138.tsv', 'ID0139.tsv', 'ID0140.tsv', 'ID0141.tsv', 'ID0142.tsv', 'ID0143.tsv', 'ID0144.tsv', 'ID0145.tsv', 'ID0146.tsv', 'ID0147.tsv', 'ID0148.tsv', 'ID0149.tsv', 'ID0150.tsv', 'ID0151.tsv', 'ID0152.tsv', 'ID0153.tsv', 'ID0154.tsv', 'ID0155.tsv', 'ID0156.tsv', 'ID0157.tsv', 'ID0158.tsv', 'ID0159.tsv', 'ID0160.tsv', 'ID0161.tsv', 'ID0162.tsv', 'ID0163.tsv', 'ID0164.tsv', 'ID0165.tsv', 'ID0166.tsv', 'ID0167.tsv', 'ID0168.tsv', 'ID0169.tsv', 'ID0170.tsv', 'ID0171.tsv', 'ID0172.tsv', 'ID0173.tsv', 'ID0174.tsv', 'ID0175.tsv', 'ID0176.tsv', 'ID0177.tsv', 'ID0178.tsv', 'ID0179.tsv', 'ID0180.tsv', 'ID0181.tsv', 'ID0182.tsv', 'ID0183.tsv', 'ID0184.tsv', 'ID0185.tsv', 'ID0186.tsv', 'ID0187.tsv', 'ID0188.tsv', 'ID0189.tsv', 'ID0190.tsv', 'ID0191.tsv', 'ID0192.tsv', 'ID0193.tsv', 'ID0194.tsv', 'ID0195.tsv', 'ID0196.tsv', 'ID0197.tsv', 'ID0198.tsv', 'ID0199.tsv', 'ID0200.tsv', 'ID0201.tsv', 'ID0202.tsv', 'ID0203.tsv', 'ID0204.tsv', 'ID0205.tsv', 'ID0206.tsv', 'ID0207.tsv', 'ID0208.tsv', 'ID0209.tsv', 'ID0210.tsv', 'ID0211.tsv', 'ID0212.tsv', 'ID0213.tsv', 'ID0214.tsv', 'ID0215.tsv', 'ID0216.tsv', 'ID0217.tsv', 'ID0218.tsv', 'ID0219.tsv', 'ID0220.tsv', 'ID0221.tsv', 'ID0222.tsv', 'ID0223.tsv', 'ID0224.tsv', 'ID0225.tsv', 'ID0226.tsv', 'ID0227.tsv', 'ID0228.tsv', 'ID0229.tsv', 'ID0230.tsv', 'ID0231.tsv', 'ID0232.tsv', 'ID0233.tsv', 'ID0234.tsv', 'ID0235.tsv', 'ID0236.tsv', 'ID0237.tsv', 'ID0238.tsv', 'ID0239.tsv', 'ID0240.tsv', 'ID0241.tsv', 'ID0242.tsv', 'ID0243.tsv', 'ID0244.tsv', 'ID0245.tsv', 'ID0246.tsv', 'ID0247.tsv', 'ID0248.tsv', 'ID0249.tsv', 'ID0250.tsv', 'ID0251.tsv', 'ID0252.tsv', 'ID0253.tsv', 'ID0254.tsv', 'ID0255.tsv', 'ID0256.tsv', 'ID0257.tsv', 'ID0258.tsv', 'ID0259.tsv', 'ID0260.tsv', 'ID0261.tsv', 'ID0262.tsv', 'ID0263.tsv', 'ID0264.tsv', 'ID0265.tsv', 'ID0266.tsv', 'ID0267.tsv', 'ID0268.tsv', 'ID0269.tsv', 'ID0270.tsv', 'ID0271.tsv', 'ID0272.tsv', 'ID0273.tsv', 'ID0274.tsv', 'ID0275.tsv', 'ID0276.tsv', 'ID0277.tsv', 'ID0278.tsv', 'ID0279.tsv', 'ID0280.tsv', 'ID0281.tsv', 'ID0282.tsv', 'ID0283.tsv', 'ID0284.tsv', 'ID0285.t ...

# %%
# Open first file for sanity check
df_head = pd.read_csv(folder_id + files[0],sep="\t")
df_head.head()
# Out:
#    798765394  20171031  201710  2017  2017.8247 MNCUSA   BOEING  USA  \
# 0  798765710  20181031  201810  2018  2018.8247    NaN      NaN  NaN
# 1  798765711  20181031  201810  2018  2018.8247    NaN      NaN  NaN
# 2  798765712  20181031  201810  2018  2018.8247    NaN      NaN  NaN
# 3  798765713  20181031  201810  2018  2018.8247    NaN      NaN  NaN
# 4  798766213  20181031  201810  2018  2018.8247    BUS  COMPANY  NaN
#
#   Unnamed: 8 Unnamed: 9  \
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN
#
#                                                                                                     ...                                                                                                    \
# 0                                                                                                   ...
# 1                                                                                                   ...
# 2                                                                                                   ...
# 3                                                                                                   ...
# 4                                                                                                   ...
#
#   Unnamed: 48 4.1             Jakarta, Jakarta Raya, Indonesia.1 ID.1 ID04.1  \
# 0    -2690876   4  Pangkalpinang, Indonesia (general), Indonesia   ID   ID00
# 1    -2679652   4               Jakarta, Jakarta Raya, Indonesia   ID   ID04
# 2    -2690876   4  Pangkalpinang, Indonesia (general), Indonesia   ID   ID00
# 3    -2690876   4  Pangkalpinang, Indonesia (general), Indonesia   ID   ID00
# 4         NaN   4               Jakarta, Jakarta Raya, Indonesia   ID   ID04
#
#   -6.17444.1 106.829.1 -2679652.1  20181031  \
# 0   -2.13333   106.133   -2690876  20181031
# 1   -6.17444   106.829   -2679652  20181031
# 2   -2.13333   106.133   -2690876  20181031
# 3   -2.13333   106.133   -2690876  20181031
# 4   -6.17444   106.829   -2679652  20181031
#
#   https://www.couriermail.com.au/news/lion-air-plane-crash-rescue-workers-retrieve-bodies-from-sea-off-jakarta/news-story/c1c420bd6bd0c7866ef07fc66d56e85a?nk=4e9ac381e0b7f5ca4c78e38004cda28b-1540943264
# 0  https://www.republika.co.id/berita/en/national...
# 1  https://www.technomag.co.zw/2018/10/30/latest-...
# 2  https://www.republika.co.id/berita/en/national...
# 3  https://www.republika.co.id/berita/en/national...
# 4  https://www.technomag.co.zw/2018/10/30/latest-...
#
# [5 rows x 58 columns]

# %%
# Read header / column names
colnames = list(pd.read_excel('./rawdata/headerfile/CSV.header.fieldids.xlsx', 
                              sheet_name='CSV.header.dailyupdates'))

for file in files:
    print('Extracting ' + file)
    df_data = pd.DataFrame()
    
    # Important: If your ID0000.tsv contains header, you can delete the header
    df_data = pd.read_csv(folder_id + file, sep="\t", names= colnames)
    df_data.to_sql(name = 'gdelt_events', con = engine, if_exists = 'append', index = False)
# Out:
# Extracting ID0000.tsv
# Extracting ID0001.tsv
# Extracting ID0002.tsv
# Extracting ID0003.tsv
# Extracting ID0004.tsv
# Extracting ID0005.tsv
# Extracting ID0006.tsv
# Extracting ID0007.tsv
# Extracting ID0008.tsv
# Extracting ID0009.tsv
# Extracting ID0010.tsv
# Extracting ID0011.tsv
# Extracting ID0012.tsv
# Extracting ID0013.tsv
# Extracting ID0014.tsv
# Extracting ID0015.tsv
# Extracting ID0016.tsv
# Extracting ID0017.tsv
# Extracting ID0018.tsv
# Extracting ID0019.tsv
# Extracting ID0020.tsv
# Extracting ID0021.tsv
# Extracting ID0022.tsv
# Extracting ID0023.tsv
# Extracting ID0024.tsv
# Extracting ID0025.tsv
# Extracting ID0026.tsv
# Extracting ID0027.tsv
# Extracting ID0028.tsv
# Extracting ID0029.tsv
# Extracting ID0030.tsv
# Extracting ID0031.tsv
# Extracting ID0032.tsv
# Extracting ID0033.tsv
# Extracting ID0034.tsv
# Extracting ID0035.tsv
# Extracting ID0036.tsv
# Extracting ID0037.tsv
# Extracting ID0038.tsv
# Extracting ID0039.tsv
# Extracting ID0040.tsv
# Extracting ID0041.tsv
# Extracting ID0042.tsv
# Extracting ID0043.tsv
# Extracting ID0044.tsv
# Extracting ID0045.tsv
# Extracting ID0046.tsv
# Extracting ID0047.tsv
# Extracting ID0048.tsv
# Extracting ID0049.tsv
# Extracting ID0050.tsv
# Extracting ID0051.tsv
# Extracting ID0052.tsv
# Extracting ID0053.tsv
# Extracting ID0054.tsv
# Extracting ID0055.tsv
# Extracting ID0056.tsv
# Extracting ID0057.tsv
# Extracting ID0058.tsv
# Extracting ID0059.tsv
# Extracting ID0060.tsv
# Extracting ID0061.tsv
# Extracting ID0062.tsv
# Extracting ID0063.tsv
# Extracting ID0064.tsv
# Extracting ID0065.tsv
# Extracting ID0066.tsv
# Extracting ID0067.tsv
# Extracting ID0068.tsv
# Extracting ID0069.tsv
# Extracting ID0070.tsv
# Extracting ID0071.tsv
# Extracting ID0072.tsv
# Extracting ID0073.tsv
# Extracting ID0074.tsv
# Extracting ID0075.tsv
# Extracting ID0076.tsv
# Extracting ID0077.tsv
# Extracting ID0078.tsv
# Extracting ID0079.tsv
# Extracting ID0080.tsv
# Extracting ID0081.tsv
# Extracting ID0082.tsv
# Extracting ID0083.tsv
# Extracting ID0084.tsv
# Extracting ID0085.tsv
# Extracting ID0086.tsv
# Extracting ID0087.tsv
# Extracting ID0088.tsv
# Extracting ID0089.tsv
# Extracting ID0090.tsv
# Extracting ID0091.tsv
# Extracting ID0092.tsv
# Extracting ID0093.tsv
# Extracting ID0094.tsv
# Extracting ID0095.tsv
# Extracting ID0096.tsv
# Extracting ID0097.tsv
# Extracting ID0098.tsv
# Extracting ID0099.tsv
# Extracting ID0100.tsv
# Extracting ID0101.tsv
# Extracting ID0102.tsv
# Extracting ID0103.tsv
# Extracting ID0104.tsv
# Extracting ID0105.tsv
# Extracting ID0106.tsv
# Extracting ID0107.tsv
# Extracting ID0108.tsv
# Extracting ID0109.tsv
# Extracting ID0110.tsv
# Extracting ID0111.tsv
# Extracting ID0112.tsv
# Extracting ID0113.tsv
# Extracting ID0114.tsv
# Extracting ID0115.tsv
# Extracting ID0116.tsv
# Extracting ID0117.tsv
# Extracting ID0118.tsv
# Extracting ID0119.tsv
# Extracting ID0120.tsv
# Extracting ID0121.tsv
# Extracting ID0122.tsv
# Extracting ID0123.tsv
# Extracting ID0124.tsv
# Extracting ID0125.tsv
# Extracting ID0126.tsv
# Extracting ID0127.tsv
# Extracting ID0128.tsv
# Extracting ID0129.tsv
# Extracting ID0130.tsv
# Extracting ID0131.tsv
# Extracting ID0132.tsv
# Extracting ID0133.tsv
# Extracting ID0134.tsv
# Extracting ID0135.tsv
# Extracting ID0136.tsv
# Extracting ID0137.tsv
# Extracting ID0138.tsv
# Extracting ID0139.tsv
# Extracting ID0140.tsv
# Extracting ID0141.tsv
# Extracting ID0142.tsv
# Extracting ID0143.tsv
# Extracting ID0144.tsv
# Extracting ID0145.tsv
# Extracting ID0146.tsv
# Extracting ID0147.tsv
# Extracting ID0148.tsv
# Extracting ID0149.tsv
# Extracting ID0150.tsv
# Extracting ID0151.tsv
# Extracting ID0152.tsv
# Extracting ID0153.tsv
# Extracting ID0154.tsv
# Extracting ID0155.tsv
# Extracting ID0156.tsv
# Extracting ID0157.tsv
# Extracting ID0158.tsv
# Extracting ID0159.tsv
# Extracting ID0160.tsv
# Extracting ID0161.tsv
# Extracting ID0162.tsv
# Extracting ID0163.tsv
# Extracting ID0164.tsv
# Extracting ID0165.tsv
# Extracting ID0166.tsv
# Extracting ID0167.tsv
# Extracting ID0168.tsv
# Extracting ID0169.tsv
# Extracting ID0170.tsv
# Extracting ID0171.tsv
# Extracting ID0172.tsv
# Extracting ID0173.tsv
# Extracting ID0174.tsv
# Extracting ID0175.tsv
# Extracting ID0176.tsv
# Extracting ID0177.tsv
# Extracting ID0178.tsv
# Extracting ID0179.tsv
# Extracting ID0180.tsv
# Extracting ID0181.tsv
# Extracting ID0182.tsv
# Extracting ID0183.tsv
# Extracting ID0184.tsv
# Extracting ID0185.tsv
# Extracting ID0186.tsv
# Extracting ID0187.tsv
# Extracting ID0188.tsv
# Extracting ID0189.tsv
# Extracting ID0190.tsv
# Extracting ID0191.tsv
# Extracting ID0192.tsv
# Extracting ID0193.tsv
# Extracting ID0194.tsv
# Extracting ID0195.tsv
# Extracting ID0196.tsv
# Extracting ID0197.tsv
# Extracting ID0198.tsv
# Extracting ID0199.tsv
# Extracting ID0200.tsv
# Extracting ID0201.tsv
# Extracting ID0202.tsv
# Extracting ID0203.tsv
# Extracting ID0204.tsv
# Extracting ID0205.tsv
# Extracting ID0206.tsv
# Extracting ID0207.tsv
# Extracting ID0208.tsv
# Extracting ID0209.tsv
# Extracting ID0210.tsv
# Extracting ID0211.tsv
# Extracting ID0212.tsv
# Extracting ID0213.tsv
# Extracting ID0214.tsv
# Extracting ID0215.tsv
# Extracting ID0216.tsv
# Extracting ID0217.tsv
# Extracting ID0218.tsv
# Extracting ID0219.tsv
# Extracting ID0220.tsv
# Extracting ID0221.tsv
# Extracting ID0222.tsv
# Extracting ID0223.tsv
# Extracting ID0224.tsv
# Extracting ID0225.tsv
# Extracting ID0226.tsv
# Extracting ID0227.tsv
# Extracting ID0228.tsv
# Extracting ID0229.tsv
# Extracting ID0230.tsv
# Extracting ID0231.tsv
# Extracting ID0232.tsv
# Extracting ID0233.tsv
# Extracting ID0234.tsv
# Extracting ID0235.tsv
# Extracting ID0236.tsv
# Extracting ID0237.tsv
# Extracting ID0238.tsv
# Extracting ID0239.tsv
# Extracting ID0240.tsv
# Extracting ID0241.tsv
# Extracting ID0242.tsv
# Extracting ID0243.tsv
# Extracting ID0244.tsv
# Extracting ID0245.tsv
# Extracting ID0246.tsv
# Extracting ID0247.tsv
# Extracting ID0248.tsv
# Extracting ID0249.tsv
# Extracting ID0250.tsv
# Extracting ID0251.tsv
# Extracting ID0252.tsv
# Extracting ID0253.tsv
# Extracting ID0254.tsv
# Extracting ID0255.tsv
# Extracting ID0256.tsv
# Extracting ID0257.tsv
# Extracting ID0258.tsv
# Extracting ID0259.tsv
# Extracting ID0260.tsv
# Extracting ID0261.tsv
# Extracting ID0262.tsv
# Extracting ID0263.tsv
# Extracting ID0264.tsv
# Extracting ID0265.tsv
# Extracting ID0266.tsv
# Extracting ID0267.tsv
# Extracting ID0268.tsv
# Extracting ID0269.tsv
# Extracting ID0270.tsv
# Extracting ID0271.tsv
# Extracting ID0272.tsv
# Extracting ID0273.tsv
# Extracting ID0274.tsv
# Extracting ID0275.tsv
# Extracting ID0276.tsv
# Extracting ID0277.tsv
# Extracting ID0278.tsv
# Extracting ID0279.tsv
# Extracting ID0280.tsv
# Extracting ID0281.tsv
# Extracting ID0282.tsv
# Extracting ID0283.tsv
# Extracting ID0284.tsv
# Extracting ID0285.tsv
# Extracting ID0286.tsv
# Extracting ID0287.tsv
# Extracting ID0288.tsv
# Extracting ID0289.tsv
# Extracting ID0290.tsv
# Extracting ID0291.tsv
# Extracting ID0292.tsv
# Extracting ID0293.tsv
# Extracting ID0294.tsv
# Extracting ID0295.tsv
# Extracting ID0296.tsv
# Extracting ID0297.tsv
# Extracting ID0298.tsv
# Extracting ID0299.tsv
# Extracting ID0300.tsv
# Extracting ID0301.tsv
# Extracting ID0302.tsv
# Extracting ID0303.tsv

# %% [markdown]
# ## Getting `GKG` data from GDELT

# %%
import requests
import lxml.html as lh

gdelt_base_url = 'http://data.gdeltproject.org/gkg/'

# get the list of all the links on the gdelt file page
page = requests.get(gdelt_base_url+'index.html')
doc = lh.fromstring(page.content)
link_list = doc.xpath("//*/ul/li/a/@href")

# separate out those links that begin with four digits
file_list = [x for x in link_list if str.isdigit(x[0:4])]
# file_list = file_list[85:]
# print(file_list)

infilecounter = 0
outfilecounter = 0

import os.path
import urllib.request
import zipfile
import glob
import operator
import pandas as pd

local_path = 'rawdata/gkg/'
fips_country_code = 'ID'

# %%
# set the month of the data collection
filemonth = ['201801', '201802', '201803', '201804', '201805', '201806', '201807', '201808', '201809', '201810']
ext = ['gkgcounts.csv.zip']

# show the list of the months
#for compressed_file in file_list[infilecounter:]:
#    if any(c in compressed_file for c in filemonth ):
#        if any (c in compressed_file for c in ext ):
#            print(compressed_file)

# %%
for compressed_file in file_list[infilecounter:]:
    if any(c in compressed_file for c in filemonth):
        if not any (c in compressed_file for c in ext ):
            continue

        print(infilecounter, ' - ', compressed_file)

        # if we dont have the compressed file stored locally, go get it. Keep trying if necessary.
        while not os.path.isfile(local_path + compressed_file):
            print('downloading, ')
    #         urllib.request.urlretrieve(url=gdelt_base_url + compressed_file,
    #         filename=local_path + compressed_file)

            resp = requests.get(url=gdelt_base_url + compressed_file)

            # assuming the subdirectory tempdata has been created:
            zfile = open(local_path + compressed_file, 'wb')
            zfile.write(resp.content)
            zfile.close()

        # extract the contents of the compressed file to a temporary directory
        print('extracting,'),
        z = zipfile.ZipFile(file=local_path + compressed_file, mode='r')
        z.extractall(path=local_path + 'tmp/')

        # parse each of the csv files in the working directory,
        print('parsing,'),

        for infile_name in glob.glob(local_path + 'tmp/*'):
            outfile_name = local_path + 'result/' + fips_country_code + '%04i.tsv' % outfilecounter
            # open the infile and outfile

            with open(infile_name, mode='r', encoding="utf8") as infile, open(outfile_name, mode='w', encoding="utf8") as outfile:
                for line in infile:
                    # extract lines with our interest country code
                    if fips_country_code in operator.itemgetter(7)(line.split('\t')):
                        outfile.write(line)
                outfilecounter += 1

            # delete the temporary file
            os.remove(infile_name)
        infilecounter += 1
        print('done')
# Out:
# 0  -  20181031.gkgcounts.csv.zip
# extracting,
# parsing,
# done
# 1  -  20181030.gkgcounts.csv.zip
# extracting,
# parsing,
# done
# 2  -  20181029.gkgcounts.csv.zip
# extracting,
# parsing,
# done
# 3  -  20181028.gkgcounts.csv.zip
# extracting,
# parsing,
# done
# 4  -  20181027.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 5  -  20181026.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 6  -  20181025.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 7  -  20181024.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 8  -  20181023.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 9  -  20181022.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 10  -  20181021.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 11  -  20181020.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 12  -  20181019.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 13  -  20181018.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 14  -  20181017.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 15  -  20181016.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 16  -  20181015.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 17  -  20181014.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 18  -  20181013.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 19  -  20181012.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 20  -  20181011.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 21  -  20181010.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 22  -  20181009.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 23  -  20181008.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 24  -  20181007.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 25  -  20181006.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 26  -  20181005.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 27  -  20181004.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 28  -  20181003.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 29  -  20181002.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 30  -  20181001.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 31  -  20180930.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 32  -  20180929.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 33  -  20180928.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 34  -  20180927.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 35  -  20180926.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 36  -  20180925.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 37  -  20180924.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 38  -  20180923.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 39  -  20180922.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 40  -  20180921.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 41  -  20180920.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 42  -  20180919.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 43  -  20180918.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 44  -  20180917.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 45  -  20180916.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 46  -  20180915.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 47  -  20180914.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 48  -  20180913.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 49  -  20180912.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 50  -  20180911.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 51  -  20180910.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 52  -  20180909.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 53  -  20180908.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 54  -  20180907.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 55  -  20180906.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 56  -  20180905.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 57  -  20180904.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 58  -  20180903.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 59  -  20180902.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 60  -  20180901.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 61  -  20180831.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 62  -  20180830.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 63  -  20180829.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 64  -  20180828.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 65  -  20180827.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 66  -  20180826.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 67  -  20180825.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 68  -  20180824.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 69  -  20180823.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 70  -  20180822.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 71  -  20180821.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 72  -  20180820.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 73  -  20180819.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 74  -  20180818.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 75  -  20180817.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 76  -  20180816.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 77  -  20180815.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 78  -  20180814.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 79  -  20180813.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 80  -  20180812.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 81  -  20180811.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 82  -  20180810.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 83  -  20180809.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 84  -  20180808.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 85  -  20180807.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 86  -  20180806.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 87  -  20180805.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 88  -  20180804.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 89  -  20180803.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 90  -  20180802.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 91  -  20180801.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 92  -  20180731.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 93  -  20180730.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 94  -  20180729.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 95  -  20180728.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 96  -  20180727.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 97  -  20180726.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 98  -  20180725.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 99  -  20180724.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 100  -  20180723.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 101  -  20180722.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 102  -  20180721.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 103  -  20180720.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 104  -  20180719.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 105  -  20180718.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 106  -  20180717.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 107  -  20180716.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 108  -  20180715.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 109  -  20180714.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 110  -  20180713.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 111  -  20180712.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 112  -  20180711.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 113  -  20180710.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 114  -  20180709.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 115  -  20180708.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 116  -  20180707.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 117  -  20180706.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 118  -  20180705.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 119  -  20180704.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 120  -  20180703.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 121  -  20180702.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 122  -  20180701.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 123  -  20180630.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 124  -  20180629.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 125  -  20180628.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 126  -  20180627.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 127  -  20180626.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 128  -  20180625.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 129  -  20180624.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 130  -  20180623.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 131  -  20180622.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 132  -  20180621.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 133  -  20180620.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 134  -  20180619.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 135  -  20180618.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 136  -  20180617.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 137  -  20180616.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 138  -  20180615.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 139  -  20180614.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 140  -  20180613.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 141  -  20180612.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 142  -  20180611.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 143  -  20180610.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 144  -  20180609.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 145  -  20180608.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 146  -  20180607.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 147  -  20180606.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 148  -  20180605.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 149  -  20180604.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 150  -  20180603.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 151  -  20180602.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 152  -  20180601.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 153  -  20180531.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 154  -  20180530.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 155  -  20180529.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 156  -  20180528.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 157  -  20180527.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 158  -  20180526.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 159  -  20180525.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 160  -  20180524.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 161  -  20180523.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 162  -  20180522.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 163  -  20180521.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 164  -  20180520.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 165  -  20180519.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 166  -  20180518.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 167  -  20180517.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 168  -  20180516.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 169  -  20180515.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 170  -  20180514.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 171  -  20180513.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 172  -  20180512.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 173  -  20180511.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 174  -  20180510.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 175  -  20180509.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 176  -  20180508.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 177  -  20180507.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 178  -  20180506.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 179  -  20180505.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 180  -  20180504.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 181  -  20180503.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 182  -  20180502.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 183  -  20180501.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 184  -  20180430.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 185  -  20180429.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 186  -  20180428.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 187  -  20180427.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 188  -  20180426.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 189  -  20180425.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 190  -  20180424.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 191  -  20180423.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 192  -  20180422.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 193  -  20180421.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 194  -  20180420.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 195  -  20180419.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 196  -  20180418.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 197  -  20180417.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 198  -  20180416.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 199  -  20180415.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 200  -  20180414.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 201  -  20180413.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 202  -  20180412.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 203  -  20180411.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 204  -  20180410.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 205  -  20180409.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 206  -  20180408.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 207  -  20180407.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 208  -  20180406.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 209  -  20180405.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 210  -  20180404.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 211  -  20180403.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 212  -  20180402.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 213  -  20180401.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 214  -  20180331.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 215  -  20180330.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 216  -  20180329.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 217  -  20180328.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 218  -  20180327.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 219  -  20180326.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 220  -  20180325.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 221  -  20180324.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 222  -  20180323.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 223  -  20180322.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 224  -  20180321.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 225  -  20180320.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 226  -  20180319.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 227  -  20180318.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 228  -  20180317.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 229  -  20180316.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 230  -  20180315.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 231  -  20180314.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 232  -  20180313.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 233  -  20180312.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 234  -  20180311.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 235  -  20180310.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 236  -  20180309.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 237  -  20180308.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 238  -  20180307.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 239  -  20180306.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 240  -  20180305.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 241  -  20180304.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 242  -  20180303.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 243  -  20180302.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 244  -  20180301.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 245  -  20180228.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 246  -  20180227.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 247  -  20180226.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 248  -  20180225.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 249  -  20180224.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 250  -  20180223.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 251  -  20180222.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 252  -  20180221.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 253  -  20180220.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 254  -  20180219.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 255  -  20180218.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 256  -  20180217.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 257  -  20180216.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 258  -  20180215.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 259  -  20180214.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 260  -  20180213.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 261  -  20180212.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 262  -  20180211.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 263  -  20180210.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 264  -  20180209.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 265  -  20180208.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 266  -  20180207.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 267  -  20180206.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 268  -  20180205.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 269  -  20180204.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 270  -  20180203.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 271  -  20180202.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 272  -  20180201.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 273  -  20180131.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 274  -  20180130.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 275  -  20180129.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 276  -  20180128.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 277  -  20180127.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 278  -  20180126.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 279  -  20180125.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 280  -  20180124.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 281  -  20180123.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 282  -  20180122.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 283  -  20180121.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 284  -  20180120.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 285  -  20180119.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 286  -  20180118.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 287  -  20180117.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 288  -  20180116.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 289  -  20180115.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 290  -  20180114.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 291  -  20180113.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 292  -  20180112.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 293  -  20180111.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 294  -  20180110.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 295  -  20180109.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 296  -  20180108.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 297  -  20180107.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 298  -  20180106.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 299  -  20180105.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 300  -  20180104.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 301  -  20180103.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 302  -  20180102.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done
# 303  -  20180101.gkgcounts.csv.zip
# downloading,
# extracting,
# parsing,
# done

# %% [markdown]
# ### Import data into SQL Database
# Import all data `GKG` into **gdelt_id_data** database in the `gdelt_gkg` table

# %%
import pymysql
import pandas as pd
from sqlalchemy import create_engine

host = 'localhost'
port = '3306'
username = 'root'
password = ''
database = 'gdelt_id_data'

# Create Connection to database
engine = create_engine('mysql+pymysql://'+username+':'+password+'@'+host+':'+port+'/'+database)
#engine = create_engine('mysql+pymysql://root: @localhost:3306/gdelt_id_data')
    
# Note: We use pymysql instead of sqlalchemy because sqlalchemy
# somehow don't allow the text query. Strange bug.

'''
conn = pymysql.connect(
    host=host,
    port=int(port),
    user=username,
    passwd=password,
    db=database,
    charset='utf8mb4')
'''


def run(sql):
    df = pd.read_sql_query(sql, engine)
    return df

# %%
from os import listdir
from os.path import isfile, join

folder_id = './rawdata/gkg/result/'
files = [f for f in listdir(folder_id) if isfile(join(folder_id, f)) if not f.startswith('.')]
print(files)
# Out:
# ['ID0000.tsv', 'ID0001.tsv', 'ID0002.tsv', 'ID0003.tsv', 'ID0004.tsv', 'ID0005.tsv', 'ID0006.tsv', 'ID0007.tsv', 'ID0008.tsv', 'ID0009.tsv', 'ID0010.tsv', 'ID0011.tsv', 'ID0012.tsv', 'ID0013.tsv', 'ID0014.tsv', 'ID0015.tsv', 'ID0016.tsv', 'ID0017.tsv', 'ID0018.tsv', 'ID0019.tsv', 'ID0020.tsv', 'ID0021.tsv', 'ID0022.tsv', 'ID0023.tsv', 'ID0024.tsv', 'ID0025.tsv', 'ID0026.tsv', 'ID0027.tsv', 'ID0028.tsv', 'ID0029.tsv', 'ID0030.tsv', 'ID0031.tsv', 'ID0032.tsv', 'ID0033.tsv', 'ID0034.tsv', 'ID0035.tsv', 'ID0036.tsv', 'ID0037.tsv', 'ID0038.tsv', 'ID0039.tsv', 'ID0040.tsv', 'ID0041.tsv', 'ID0042.tsv', 'ID0043.tsv', 'ID0044.tsv', 'ID0045.tsv', 'ID0046.tsv', 'ID0047.tsv', 'ID0048.tsv', 'ID0049.tsv', 'ID0050.tsv', 'ID0051.tsv', 'ID0052.tsv', 'ID0053.tsv', 'ID0054.tsv', 'ID0055.tsv', 'ID0056.tsv', 'ID0057.tsv', 'ID0058.tsv', 'ID0059.tsv', 'ID0060.tsv', 'ID0061.tsv', 'ID0062.tsv', 'ID0063.tsv', 'ID0064.tsv', 'ID0065.tsv', 'ID0066.tsv', 'ID0067.tsv', 'ID0068.tsv', 'ID0069.tsv', 'ID0070.tsv', 'ID0071.tsv', 'ID0072.tsv', 'ID0073.tsv', 'ID0074.tsv', 'ID0075.tsv', 'ID0076.tsv', 'ID0077.tsv', 'ID0078.tsv', 'ID0079.tsv', 'ID0080.tsv', 'ID0081.tsv', 'ID0082.tsv', 'ID0083.tsv', 'ID0084.tsv', 'ID0085.tsv', 'ID0086.tsv', 'ID0087.tsv', 'ID0088.tsv', 'ID0089.tsv', 'ID0090.tsv', 'ID0091.tsv', 'ID0092.tsv', 'ID0093.tsv', 'ID0094.tsv', 'ID0095.tsv', 'ID0096.tsv', 'ID0097.tsv', 'ID0098.tsv', 'ID0099.tsv', 'ID0100.tsv', 'ID0101.tsv', 'ID0102.tsv', 'ID0103.tsv', 'ID0104.tsv', 'ID0105.tsv', 'ID0106.tsv', 'ID0107.tsv', 'ID0108.tsv', 'ID0109.tsv', 'ID0110.tsv', 'ID0111.tsv', 'ID0112.tsv', 'ID0113.tsv', 'ID0114.tsv', 'ID0115.tsv', 'ID0116.tsv', 'ID0117.tsv', 'ID0118.tsv', 'ID0119.tsv', 'ID0120.tsv', 'ID0121.tsv', 'ID0122.tsv', 'ID0123.tsv', 'ID0124.tsv', 'ID0125.tsv', 'ID0126.tsv', 'ID0127.tsv', 'ID0128.tsv', 'ID0129.tsv', 'ID0130.tsv', 'ID0131.tsv', 'ID0132.tsv', 'ID0133.tsv', 'ID0134.tsv', 'ID0135.tsv', 'ID0136.tsv', 'ID0137.tsv', 'ID0138.tsv', 'ID0139.tsv', 'ID0140.tsv', 'ID0141.tsv', 'ID0142.tsv', 'ID0143.tsv', 'ID0144.tsv', 'ID0145.tsv', 'ID0146.tsv', 'ID0147.tsv', 'ID0148.tsv', 'ID0149.tsv', 'ID0150.tsv', 'ID0151.tsv', 'ID0152.tsv', 'ID0153.tsv', 'ID0154.tsv', 'ID0155.tsv', 'ID0156.tsv', 'ID0157.tsv', 'ID0158.tsv', 'ID0159.tsv', 'ID0160.tsv', 'ID0161.tsv', 'ID0162.tsv', 'ID0163.tsv', 'ID0164.tsv', 'ID0165.tsv', 'ID0166.tsv', 'ID0167.tsv', 'ID0168.tsv', 'ID0169.tsv', 'ID0170.tsv', 'ID0171.tsv', 'ID0172.tsv', 'ID0173.tsv', 'ID0174.tsv', 'ID0175.tsv', 'ID0176.tsv', 'ID0177.tsv', 'ID0178.tsv', 'ID0179.tsv', 'ID0180.tsv', 'ID0181.tsv', 'ID0182.tsv', 'ID0183.tsv', 'ID0184.tsv', 'ID0185.tsv', 'ID0186.tsv', 'ID0187.tsv', 'ID0188.tsv', 'ID0189.tsv', 'ID0190.tsv', 'ID0191.tsv', 'ID0192.tsv', 'ID0193.tsv', 'ID0194.tsv', 'ID0195.tsv', 'ID0196.tsv', 'ID0197.tsv', 'ID0198.tsv', 'ID0199.tsv', 'ID0200.tsv', 'ID0201.tsv', 'ID0202.tsv', 'ID0203.tsv', 'ID0204.tsv', 'ID0205.tsv', 'ID0206.tsv', 'ID0207.tsv', 'ID0208.tsv', 'ID0209.tsv', 'ID0210.tsv', 'ID0211.tsv', 'ID0212.tsv', 'ID0213.tsv', 'ID0214.tsv', 'ID0215.tsv', 'ID0216.tsv', 'ID0217.tsv', 'ID0218.tsv', 'ID0219.tsv', 'ID0220.tsv', 'ID0221.tsv', 'ID0222.tsv', 'ID0223.tsv', 'ID0224.tsv', 'ID0225.tsv', 'ID0226.tsv', 'ID0227.tsv', 'ID0228.tsv', 'ID0229.tsv', 'ID0230.tsv', 'ID0231.tsv', 'ID0232.tsv', 'ID0233.tsv', 'ID0234.tsv', 'ID0235.tsv', 'ID0236.tsv', 'ID0237.tsv', 'ID0238.tsv', 'ID0239.tsv', 'ID0240.tsv', 'ID0241.tsv', 'ID0242.tsv', 'ID0243.tsv', 'ID0244.tsv', 'ID0245.tsv', 'ID0246.tsv', 'ID0247.tsv', 'ID0248.tsv', 'ID0249.tsv', 'ID0250.tsv', 'ID0251.tsv', 'ID0252.tsv', 'ID0253.tsv', 'ID0254.tsv', 'ID0255.tsv', 'ID0256.tsv', 'ID0257.tsv', 'ID0258.tsv', 'ID0259.tsv', 'ID0260.tsv', 'ID0261.tsv', 'ID0262.tsv', 'ID0263.tsv', 'ID0264.tsv', 'ID0265.tsv', 'ID0266.tsv', 'ID0267.tsv', 'ID0268.tsv', 'ID0269.tsv', 'ID0270.tsv', 'ID0271.tsv', 'ID0272.tsv', 'ID0273.tsv', 'ID0274.tsv', 'ID0275.tsv', 'ID0276.tsv', 'ID0277.tsv', 'ID0278.tsv', 'ID0279.tsv', 'ID0280.tsv', 'ID0281.tsv', 'ID0282.tsv', 'ID0283.tsv', 'ID0284.tsv', 'ID0285.t ...

# %%
# Open first file for sanity check
df_head = pd.read_csv(folder_id + files[0],sep="\t")
df_head.head()
# Out:
#    20181031  1   CRISISLEX_T02_INJURED    4 Unnamed: 4  1.1  \
# 0  20181031  1      CRISISLEX_T03_DEAD  121        NaN    4
# 1  20181031  2      CRISISLEX_T03_DEAD   15        NaN    4
# 2  20181031  1                  AFFECT  200    amilies    1
# 3  20181031  3  CRISISLEX_CRISISLEXREC    7        NaN    4
# 4  20181031  6                    KILL  234        NaN    1
#
#                                  Indonesia  ID  ID.1       -5      120  \
# 0         Jakarta, Jakarta Raya, Indonesia  ID  ID04 -6.17444  106.829
# 1  Tanjung Karawang, Jawa Barat, Indonesia  ID  ID30 -5.92611  107.003
# 2                                Indonesia  ID    ID -5.00000  120.000
# 3         Jakarta, Jakarta Raya, Indonesia  ID  ID04 -6.17444  106.829
# 4                                Indonesia  ID    ID -5.00000  120.000
#
#        ID.2                                        Unnamed: 12  \
# 0  -2679652  798789809,798790134,798790149,798790150,798791...
# 1  -2681536                                                NaN
# 2        ID            798939629,798941414,798941415,798941416
# 3  -2679652  798851144,798851240,798851241,798851250,798826...
# 4        ID  798765711,798805082,798805083,798767901,798805...
#
#                                             en.ce.cn  \
# 0                                         siasat.com
# 1                            en.tempo.co;en.tempo.co
# 2                                      reliefweb.int
# 3  businessinsider.com.au;msn.com;businessinsider...
# 4  singaporestar.com;nhandan.org.vn;castanet.net;...
#
#   http://en.ce.cn/World/big-news/201810/31/t20181031_30673786.shtml
# 0  https://www.siasat.com/news/indonesias-deadlie...
# 1  http://en.tempo.co/read/news/2018/10/31/056923...
# 2  https://reliefweb.int/report/indonesia/how-car...
# 3  https://www.businessinsider.com.au/the-10-most...
# 4  https://www.singaporestar.com/news/258218110/c...

# %%
# Read header / column names
colnames = list(pd.read_excel('./rawdata/headerfile/CSV.header.gkg.xlsx'))

for file in files:
    print('Extracting ' + file)
    df_data = pd.DataFrame()
    
    # Important: If your ID0000.tsv contains header, you can delete the header
    df_data = pd.read_csv(folder_id + file, sep="\t", names= colnames)
    df_data.to_sql(name = 'gdelt_gkg', con = engine, if_exists = 'append', index = False)
# Out:
# Extracting ID0000.tsv
# Extracting ID0001.tsv
# Extracting ID0002.tsv
# Extracting ID0003.tsv
# Extracting ID0004.tsv
# Extracting ID0005.tsv
# Extracting ID0006.tsv
# Extracting ID0007.tsv
# Extracting ID0008.tsv
# Extracting ID0009.tsv
# Extracting ID0010.tsv
# Extracting ID0011.tsv
# Extracting ID0012.tsv
# Extracting ID0013.tsv
# Extracting ID0014.tsv
# Extracting ID0015.tsv
# Extracting ID0016.tsv
# Extracting ID0017.tsv
# Extracting ID0018.tsv
# Extracting ID0019.tsv
# Extracting ID0020.tsv
# Extracting ID0021.tsv
# Extracting ID0022.tsv
# Extracting ID0023.tsv
# Extracting ID0024.tsv
# Extracting ID0025.tsv
# Extracting ID0026.tsv
# Extracting ID0027.tsv
# Extracting ID0028.tsv
# Extracting ID0029.tsv
# Extracting ID0030.tsv
# Extracting ID0031.tsv
# Extracting ID0032.tsv
# Extracting ID0033.tsv
# Extracting ID0034.tsv
# Extracting ID0035.tsv
# Extracting ID0036.tsv
# Extracting ID0037.tsv
# Extracting ID0038.tsv
# Extracting ID0039.tsv
# Extracting ID0040.tsv
# Extracting ID0041.tsv
# Extracting ID0042.tsv
# Extracting ID0043.tsv
# Extracting ID0044.tsv
# Extracting ID0045.tsv
# Extracting ID0046.tsv
# Extracting ID0047.tsv
# Extracting ID0048.tsv
# Extracting ID0049.tsv
# Extracting ID0050.tsv
# Extracting ID0051.tsv
# Extracting ID0052.tsv
# Extracting ID0053.tsv
# Extracting ID0054.tsv
# Extracting ID0055.tsv
# Extracting ID0056.tsv
# Extracting ID0057.tsv
# Extracting ID0058.tsv
# Extracting ID0059.tsv
# Extracting ID0060.tsv
# Extracting ID0061.tsv
# Extracting ID0062.tsv
# Extracting ID0063.tsv
# Extracting ID0064.tsv
# Extracting ID0065.tsv
# Extracting ID0066.tsv
# Extracting ID0067.tsv
# Extracting ID0068.tsv
# Extracting ID0069.tsv
# Extracting ID0070.tsv
# Extracting ID0071.tsv
# Extracting ID0072.tsv
# Extracting ID0073.tsv
# Extracting ID0074.tsv
# Extracting ID0075.tsv
# Extracting ID0076.tsv
# Extracting ID0077.tsv
# Extracting ID0078.tsv
# Extracting ID0079.tsv
# Extracting ID0080.tsv
# Extracting ID0081.tsv
# Extracting ID0082.tsv
# Extracting ID0083.tsv
# Extracting ID0084.tsv
# Extracting ID0085.tsv
# Extracting ID0086.tsv
# Extracting ID0087.tsv
# Extracting ID0088.tsv
# Extracting ID0089.tsv
# Extracting ID0090.tsv
# Extracting ID0091.tsv
# Extracting ID0092.tsv
# Extracting ID0093.tsv
# Extracting ID0094.tsv
# Extracting ID0095.tsv
# Extracting ID0096.tsv
# Extracting ID0097.tsv
# Extracting ID0098.tsv
# Extracting ID0099.tsv
# Extracting ID0100.tsv
# Extracting ID0101.tsv
# Extracting ID0102.tsv
# Extracting ID0103.tsv
# Extracting ID0104.tsv
# Extracting ID0105.tsv
# Extracting ID0106.tsv
# Extracting ID0107.tsv
# Extracting ID0108.tsv
# Extracting ID0109.tsv
# Extracting ID0110.tsv
# Extracting ID0111.tsv
# Extracting ID0112.tsv
# Extracting ID0113.tsv
# Extracting ID0114.tsv
# Extracting ID0115.tsv
# Extracting ID0116.tsv
# Extracting ID0117.tsv
# Extracting ID0118.tsv
# Extracting ID0119.tsv
# Extracting ID0120.tsv
# Extracting ID0121.tsv
# Extracting ID0122.tsv
# Extracting ID0123.tsv
# Extracting ID0124.tsv
# Extracting ID0125.tsv
# Extracting ID0126.tsv
# Extracting ID0127.tsv
# Extracting ID0128.tsv
# Extracting ID0129.tsv
# Extracting ID0130.tsv
# Extracting ID0131.tsv
# Extracting ID0132.tsv
# Extracting ID0133.tsv
# Extracting ID0134.tsv
# Extracting ID0135.tsv
# Extracting ID0136.tsv
# Extracting ID0137.tsv
# Extracting ID0138.tsv
# Extracting ID0139.tsv
# Extracting ID0140.tsv
# Extracting ID0141.tsv
# Extracting ID0142.tsv
# Extracting ID0143.tsv
# Extracting ID0144.tsv
# Extracting ID0145.tsv
# Extracting ID0146.tsv
# Extracting ID0147.tsv
# Extracting ID0148.tsv
# Extracting ID0149.tsv
# Extracting ID0150.tsv
# Extracting ID0151.tsv
# Extracting ID0152.tsv
# Extracting ID0153.tsv
# Extracting ID0154.tsv
# Extracting ID0155.tsv
# Extracting ID0156.tsv
# Extracting ID0157.tsv
# Extracting ID0158.tsv
# Extracting ID0159.tsv
# Extracting ID0160.tsv
# Extracting ID0161.tsv
# Extracting ID0162.tsv
# Extracting ID0163.tsv
# Extracting ID0164.tsv
# Extracting ID0165.tsv
# Extracting ID0166.tsv
# Extracting ID0167.tsv
# Extracting ID0168.tsv
# Extracting ID0169.tsv
# Extracting ID0170.tsv
# Extracting ID0171.tsv
# Extracting ID0172.tsv
# Extracting ID0173.tsv
# Extracting ID0174.tsv
# Extracting ID0175.tsv
# Extracting ID0176.tsv
# Extracting ID0177.tsv
# Extracting ID0178.tsv
# Extracting ID0179.tsv
# Extracting ID0180.tsv
# Extracting ID0181.tsv
# Extracting ID0182.tsv
# Extracting ID0183.tsv
# Extracting ID0184.tsv
# Extracting ID0185.tsv
# Extracting ID0186.tsv
# Extracting ID0187.tsv
# Extracting ID0188.tsv
# Extracting ID0189.tsv
# Extracting ID0190.tsv
# Extracting ID0191.tsv
# Extracting ID0192.tsv
# Extracting ID0193.tsv
# Extracting ID0194.tsv
# Extracting ID0195.tsv
# Extracting ID0196.tsv
# Extracting ID0197.tsv
# Extracting ID0198.tsv
# Extracting ID0199.tsv
# Extracting ID0200.tsv
# Extracting ID0201.tsv
# Extracting ID0202.tsv
# Extracting ID0203.tsv
# Extracting ID0204.tsv
# Extracting ID0205.tsv
# Extracting ID0206.tsv
# Extracting ID0207.tsv
# Extracting ID0208.tsv
# Extracting ID0209.tsv
# Extracting ID0210.tsv
# Extracting ID0211.tsv
# Extracting ID0212.tsv
# Extracting ID0213.tsv
# Extracting ID0214.tsv
# Extracting ID0215.tsv
# Extracting ID0216.tsv
# Extracting ID0217.tsv
# Extracting ID0218.tsv
# Extracting ID0219.tsv
# Extracting ID0220.tsv
# Extracting ID0221.tsv
# Extracting ID0222.tsv
# Extracting ID0223.tsv
# Extracting ID0224.tsv
# Extracting ID0225.tsv
# Extracting ID0226.tsv
# Extracting ID0227.tsv
# Extracting ID0228.tsv
# Extracting ID0229.tsv
# Extracting ID0230.tsv
# Extracting ID0231.tsv
# Extracting ID0232.tsv
# Extracting ID0233.tsv
# Extracting ID0234.tsv
# Extracting ID0235.tsv
# Extracting ID0236.tsv
# Extracting ID0237.tsv
# Extracting ID0238.tsv
# Extracting ID0239.tsv
# Extracting ID0240.tsv
# Extracting ID0241.tsv
# Extracting ID0242.tsv
# Extracting ID0243.tsv
# Extracting ID0244.tsv
# Extracting ID0245.tsv
# Extracting ID0246.tsv
# Extracting ID0247.tsv
# Extracting ID0248.tsv
# Extracting ID0249.tsv
# Extracting ID0250.tsv
# Extracting ID0251.tsv
# Extracting ID0252.tsv
# Extracting ID0253.tsv
# Extracting ID0254.tsv
# Extracting ID0255.tsv
# Extracting ID0256.tsv
# Extracting ID0257.tsv
# Extracting ID0258.tsv
# Extracting ID0259.tsv
# Extracting ID0260.tsv
# Extracting ID0261.tsv
# Extracting ID0262.tsv
# Extracting ID0263.tsv
# Extracting ID0264.tsv
# Extracting ID0265.tsv
# Extracting ID0266.tsv
# Extracting ID0267.tsv
# Extracting ID0268.tsv
# Extracting ID0269.tsv
# Extracting ID0270.tsv
# Extracting ID0271.tsv
# Extracting ID0272.tsv
# Extracting ID0273.tsv
# Extracting ID0274.tsv
# Extracting ID0275.tsv
# Extracting ID0276.tsv
# Extracting ID0277.tsv
# Extracting ID0278.tsv
# Extracting ID0279.tsv
# Extracting ID0280.tsv
# Extracting ID0281.tsv
# Extracting ID0282.tsv
# Extracting ID0283.tsv
# Extracting ID0284.tsv
# Extracting ID0285.tsv
# Extracting ID0286.tsv
# Extracting ID0287.tsv
# Extracting ID0288.tsv
# Extracting ID0289.tsv
# Extracting ID0290.tsv
# Extracting ID0291.tsv
# Extracting ID0292.tsv
# Extracting ID0293.tsv
# Extracting ID0294.tsv
# Extracting ID0295.tsv
# Extracting ID0296.tsv
# Extracting ID0297.tsv
# Extracting ID0298.tsv
# Extracting ID0299.tsv
# Extracting ID0300.tsv
# Extracting ID0301.tsv
# Extracting ID0302.tsv
# Extracting ID0303.tsv
